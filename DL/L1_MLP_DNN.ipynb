# %% [markdown]
# <a href="https://colab.research.google.com/github/dragoa/MachineLearning/blob/main/DL/L1_MLP_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Deep Neural Network (DNN)

# %%
! pip install tensorflow -q

# %% [markdown]
# ## 1.1 Refresh: build a Single Layer Perceptron
# Let's build a single layer perceptron composed by one dense layer.<br>

# %% [markdown]
# <img alt="Single Layer Perceptron with 2 inputs" width="500" caption="Single Layer Perceptron with 2 inputs" src="https://github.com/dragoa/MachineLearning/blob/main/DL/imgs/A-single-layer-perceptron-with-two-inputs.png?raw=1"/>

# %%
from keras.models import Sequential
from keras.layers import Dense

# Define the number of inputs
n_input_nodes = 2

# First define the model
model = Sequential() # Sequential() lets us define a linear stack of network layers.

# define our single fully connected network layer
dense_layer = Dense(n_input_nodes, activation='sigmoid',kernel_initializer="Ones",bias_initializer="Ones")

# Add the dense layer to the model
model.add(dense_layer)

# %% [markdown]
# ## 1.2 Refresh: build a Multilayer perceptron
# Let's build a multilayer perceptron; MLPs are fully connected, each node in one layer connects with a certain weight to every node in the following layer.
#
# Try to build one composed by two hidden dense layer with ReLU activation and one dense output layer(units=1) with sigmoid activation.

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Generate dummy data
train_data = np.random.random((1000, 100))
train_labels = np.random.randint(2, size=(1000, 1))  # Reshape to (1000, 1)
test_data = np.random.random((100, 100))
test_labels = np.random.randint(2, size=(100, 1))  # Reshape to (100, 1)

# Build your first model by creating a Sequential object and then adding 3 Dense layers:
units = 32
# Create a Sequential
model = Sequential()
# Add a Dense layer with 32 neurons, with relu as activation function and input dimension equal to the number of features
model.add(Dense(units, activation='relu', input_dim=train_data.shape[1]))
# Add a Dense layer with 32 neurons, with relu as activation function
model.add(Dense(units, activation='relu'))  # Removed unnecessary variable
# To produce the output Add a Dense layer with 1 neurons, with sigmoid as activation function
model.add(Dense(1, activation='sigmoid'))  # Changed variable name

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model, iterating on the data in batches of 32 samples
# The fit function output is a History object. The history.history attribute is a record of
# training loss values and metrics values at successive epochs, as well as validation loss values
# and validation metrics values
history = model.fit(train_data, train_labels, epochs=30, batch_size=32)
_, train_acc = model.evaluate(train_data, train_labels, verbose=1)
_, test_acc = model.evaluate(test_data, test_labels, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/30
# 32/32 [==============================] - 4s 7ms/step - loss: 0.6962 - accuracy: 0.5190
# Epoch 2/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5430
# Epoch 3/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6830 - accuracy: 0.5570
# Epoch 4/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6797 - accuracy: 0.5540
# Epoch 5/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6750 - accuracy: 0.5740
# Epoch 6/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6706 - accuracy: 0.5920
# Epoch 7/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6665 - accuracy: 0.5940
# Epoch 8/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.6180
# Epoch 9/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6496 - accuracy: 0.6230
# Epoch 10/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6515 - accuracy: 0.6110
# Epoch 11/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6352 - accuracy: 0.6490
# Epoch 12/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6301 - accuracy: 0.6480
# Epoch 13/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6193 - accuracy: 0.6730
# Epoch 14/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6148 - accuracy: 0.6670
# Epoch 15/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.6004 - accuracy: 0.6900
# Epoch 16/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5950 - accuracy: 0.7000
# Epoch 17/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5832 - accuracy: 0.7050
# Epoch 18/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5666 - accuracy: 0.7200
# Epoch 19/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5488 - accuracy: 0.7330
# Epoch 20/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5367 - accuracy: 0.7540
# Epoch 21/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5176 - accuracy: 0.7700
# Epoch 22/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.5063 - accuracy: 0.7750
# Epoch 23/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5133 - accuracy: 0.7350
# Epoch 24/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4866 - accuracy: 0.7750
# Epoch 25/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4709 - accuracy: 0.7740
# Epoch 26/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4720 - accuracy: 0.7970
# Epoch 27/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4282 - accuracy: 0.8360
# Epoch 28/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4162 - accuracy: 0.8350
# Epoch 29/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3935 - accuracy: 0.8410
# Epoch 30/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3868 - accuracy: 0.8510
# 32/32 [==============================] - 1s 8ms/step - loss: 0.3651 - accuracy: 0.8850
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8672 - accuracy: 0.5200
# Train: 0.885, Test: 0.520

# %% [markdown]
# # 1.3 Build a Deep Neural Network
# In this section we will:
# *  1.2.1 Import the dataset
# *  1.2.2 Build a model
# *  1.2.3 Train the model
# *  1.2.4 Evaluate the model

# %% [markdown]
# ## 1.3.1 Import the Dataset
# Fashion-MNIST is a dataset of Zalando’s article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. <br>
# Each example is a 28×28 grayscale image, associated with a label from 10 classes.<br>
# <img src="https://res.cloudinary.com/practicaldev/image/fetch/s--s6xGmaZX--/c_imagga_scale,f_auto,fl_progressive,h_900,q_auto,w_1600/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png" width="600px"><br>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
mnist_fashion = tf.keras.datasets.fashion_mnist

(x_learn, y_learn),(x_test, y_test) = mnist_fashion.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print("X Learn:", x_learn.shape, type(x_learn))
print("X Test:", x_test.shape, type(x_test))
print("Y Learn:", y_learn.shape, type(y_learn))
# Out:
# X Learn: (60000, 28, 28) <class 'numpy.ndarray'>
# X Test: (10000, 28, 28) <class 'numpy.ndarray'>
# Y Learn: (60000,) <class 'numpy.ndarray'>

# %%
x_learn, x_test = x_learn / 255.0, x_test / 255.0 # normalization
x_train, x_val, y_train, y_val = train_test_split(x_learn, y_learn, test_size=0.3, random_state=42) # split learn in train,val
num_classes = 10 # Fashion-MNIST classes

print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (42000, 28, 28) (18000, 28, 28) (10000, 28, 28)

# %% [markdown]
# #### Plot some sample from the training set

# %% [markdown]
# Displaying the matrix X is not useful at all, they are only pixels values. Instead what we can do is to reconstruct the images starting from those pixels.

# %%
import matplotlib.pyplot as plt

i = 0
# reshaping and reconstructiong the image
picture = np.reshape(x_learn[i,:], (28,28))

print(y_learn[i])
fig, ax = plt.subplots()
ax.imshow(picture, cmap=plt.cm.gray)
ax.axis('off')
# Out:
# 9
# (-0.5, 27.5, 27.5, -0.5)

# %%
import matplotlib.pyplot as plt
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(6,6))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## 1.3.2 Build a Model
#
# A Deep Neural Network is a neural network composed by many layers and consequently it has a deeper structure. The number of layers in the network depends on different factors: for example on the data available, on the complexity of the problem, on the computational power and so on.
# The value produced as output by a neuron is determined by the input the neuron receives and by the activation function. There exists different choices for the activation function. One of the most used is Relu but it depends on the data and on the network architecture.

# %% [markdown]
# #### Build a model with this structure: Flatten+Dense(ReLU)+Dense(ReLU)+Dense(ReLU)+Dense(ReLU)+Dense(softmax)

# %%
from keras.layers import Flatten
# https://keras.io/layers/core/
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu'))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# When we are building a model there are many design choises that we must operate: the choice of a Loss Function, the Metrics and the Optimizer.<br>
#
# **Loss functions** are used to compare the network's predicted output  with the real output, in each pass of the backpropagations algorithm<br>
# Common loss functions are: mean-squared error, cross-entropy, and so on...<br><br>
# **Metrics** are used to evaluate a model; common metrics are precision, recall, accuracy, auc,..<br>
#
# The **Optimizer** determines the update rules of the weights. The performance and update speed may heavily vary from optimizer to optimizer; in choosing an optimizer what's important to consider is the network depth, the type of layers and the type of data.<br>
# The gif below give an idea on how different Optimizers work.<br>
#
# <img src="https://user-images.githubusercontent.com/11681225/49325458-fc785480-f585-11e8-8d2a-9012d6024c6e.gif" width="460px">

# %% [markdown]
# #### Configures the model for training

# %%
# Optimizers    https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
from keras.optimizers.legacy import Adam, SGD, Adadelta, Adagrad, Adamax, Nadam, RMSprop

adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
sgd = SGD(learning_rate=0.001, momentum=0.0, decay=0.0, nesterov=False)
adad = Adadelta(learning_rate=1.0,rho=0.95,epsilon=None,decay=0.0)
adag = Adagrad(learning_rate=0.01,epsilon=None,decay=0.0)
adamax = Adamax(learning_rate=0.002,beta_1=0.9,beta_2=0.999,epsilon=None,decay=0.0)
nadam = Nadam(learning_rate=0.002,beta_1=0.9,beta_2=0.999,epsilon=None,schedule_decay=0.004)
rms = RMSprop(learning_rate=0.001,rho=0.9,epsilon=None,decay=0.0)

# Losses    https://keras.io/losses/
loss = ['sparse_categorical_crossentropy','mean_squared_error','mean_absolute_error',
        'categorical_crossentropy','categorical_hinge']

# Metrics    https://www.tensorflow.org/api_docs/python/tf/metrics
metrics = ['accuracy','precision','recall']

# %% [markdown]
# ## 1.3.3 Train the model
# The batch size is a number of samples processed before the model is updated.<br>
# The number of epochs is the number of complete passes through the training dataset.

# %%
# Compile the model you created before using
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(optimizer=adam, loss=loss[0], metrics=metrics[0])

batch_size = 128
epochs = 50
# fit your model and save the returned value as "history".
# Use both the train and validation set
# Set both properly the batch size value and the epochs value
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2, validation_data=(x_val, y_val))
# Evaluate the model
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/50
# 329/329 - 5s - loss: 0.5567 - accuracy: 0.8023 - val_loss: 0.4336 - val_accuracy: 0.8448 - 5s/epoch - 15ms/step
# Epoch 2/50
# 329/329 - 2s - loss: 0.3831 - accuracy: 0.8600 - val_loss: 0.3775 - val_accuracy: 0.8604 - 2s/epoch - 6ms/step
# Epoch 3/50
# 329/329 - 3s - loss: 0.3426 - accuracy: 0.8735 - val_loss: 0.3637 - val_accuracy: 0.8688 - 3s/epoch - 10ms/step
# Epoch 4/50
# 329/329 - 1s - loss: 0.3177 - accuracy: 0.8834 - val_loss: 0.3651 - val_accuracy: 0.8690 - 1s/epoch - 4ms/step
# Epoch 5/50
# 329/329 - 1s - loss: 0.2933 - accuracy: 0.8893 - val_loss: 0.3759 - val_accuracy: 0.8606 - 1s/epoch - 3ms/step
# Epoch 6/50
# 329/329 - 1s - loss: 0.2763 - accuracy: 0.8958 - val_loss: 0.3493 - val_accuracy: 0.8762 - 1s/epoch - 3ms/step
# Epoch 7/50
# 329/329 - 1s - loss: 0.2664 - accuracy: 0.9001 - val_loss: 0.3213 - val_accuracy: 0.8846 - 1s/epoch - 3ms/step
# Epoch 8/50
# 329/329 - 1s - loss: 0.2576 - accuracy: 0.9036 - val_loss: 0.3183 - val_accuracy: 0.8843 - 1s/epoch - 3ms/step
# Epoch 9/50
# 329/329 - 1s - loss: 0.2412 - accuracy: 0.9089 - val_loss: 0.3155 - val_accuracy: 0.8885 - 1s/epoch - 3ms/step
# Epoch 10/50
# 329/329 - 1s - loss: 0.2339 - accuracy: 0.9112 - val_loss: 0.3269 - val_accuracy: 0.8811 - 1s/epoch - 3ms/step
# Epoch 11/50
# 329/329 - 1s - loss: 0.2214 - accuracy: 0.9155 - val_loss: 0.3252 - val_accuracy: 0.8843 - 1s/epoch - 3ms/step
# Epoch 12/50
# 329/329 - 1s - loss: 0.2233 - accuracy: 0.9154 - val_loss: 0.3286 - val_accuracy: 0.8804 - 1s/epoch - 3ms/step
# Epoch 13/50
# 329/329 - 2s - loss: 0.2109 - accuracy: 0.9191 - val_loss: 0.3232 - val_accuracy: 0.8889 - 2s/epoch - 5ms/step
# Epoch 14/50
# 329/329 - 1s - loss: 0.2033 - accuracy: 0.9221 - val_loss: 0.3180 - val_accuracy: 0.8923 - 1s/epoch - 5ms/step
# Epoch 15/50
# 329/329 - 1s - loss: 0.1918 - accuracy: 0.9279 - val_loss: 0.3309 - val_accuracy: 0.8873 - 1s/epoch - 3ms/step
# Epoch 16/50
# 329/329 - 1s - loss: 0.1886 - accuracy: 0.9284 - val_loss: 0.3281 - val_accuracy: 0.8933 - 1s/epoch - 3ms/step
# Epoch 17/50
# 329/329 - 1s - loss: 0.1794 - accuracy: 0.9320 - val_loss: 0.3401 - val_accuracy: 0.8882 - 1s/epoch - 3ms/step
# Epoch 18/50
# 329/329 - 1s - loss: 0.1788 - accuracy: 0.9324 - val_loss: 0.3572 - val_accuracy: 0.8853 - 1s/epoch - 3ms/step
# Epoch 19/50
# 329/329 - 1s - loss: 0.1695 - accuracy: 0.9341 - val_loss: 0.3359 - val_accuracy: 0.8911 - 1s/epoch - 3ms/step
# Epoch 20/50
# 329/329 - 1s - loss: 0.1643 - accuracy: 0.9367 - val_loss: 0.3668 - val_accuracy: 0.8934 - 1s/epoch - 3ms/step
# Epoch 21/50
# 329/329 - 1s - loss: 0.1618 - accuracy: 0.9388 - val_loss: 0.3463 - val_accuracy: 0.8897 - 1s/epoch - 3ms/step
# Epoch 22/50
# 329/329 - 1s - loss: 0.1573 - accuracy: 0.9393 - val_loss: 0.3288 - val_accuracy: 0.8969 - 1s/epoch - 3ms/step
# Epoch 23/50
# 329/329 - 1s - loss: 0.1438 - accuracy: 0.9445 - val_loss: 0.3821 - val_accuracy: 0.8947 - 1s/epoch - 3ms/step
# Epoch 24/50
# 329/329 - 2s - loss: 0.1452 - accuracy: 0.9441 - val_loss: 0.3652 - val_accuracy: 0.8918 - 2s/epoch - 5ms/step
# Epoch 25/50
# 329/329 - 2s - loss: 0.1402 - accuracy: 0.9459 - val_loss: 0.3801 - val_accuracy: 0.8932 - 2s/epoch - 5ms/step
# Epoch 26/50
# 329/329 - 1s - loss: 0.1357 - accuracy: 0.9480 - val_loss: 0.3796 - val_accuracy: 0.8916 - 1s/epoch - 3ms/step
# Epoch 27/50
# 329/329 - 1s - loss: 0.1395 - accuracy: 0.9472 - val_loss: 0.3726 - val_accuracy: 0.8949 - 1s/epoch - 3ms/step
# Epoch 28/50
# 329/329 - 1s - loss: 0.1239 - accuracy: 0.9519 - val_loss: 0.3921 - val_accuracy: 0.8929 - 1s/epoch - 3ms/step
# Epoch 29/50
# 329/329 - 1s - loss: 0.1279 - accuracy: 0.9505 - val_loss: 0.4041 - val_accuracy: 0.8878 - 1s/epoch - 3ms/step
# Epoch 30/50
# 329/329 - 1s - loss: 0.1220 - accuracy: 0.9542 - val_loss: 0.3754 - val_accuracy: 0.8942 - 1s/epoch - 3ms/step
# Epoch 31/50
# 329/329 - 1s - loss: 0.1171 - accuracy: 0.9544 - val_loss: 0.3858 - val_accuracy: 0.8952 - 1s/epoch - 3ms/step
# Epoch 32/50
# 329/329 - 1s - loss: 0.1128 - accuracy: 0.9564 - val_loss: 0.4248 - val_accuracy: 0.8951 - 1s/epoch - 3ms/step
# Epoch 33/50
# 329/329 - 1s - loss: 0.1184 - accuracy: 0.9552 - val_loss: 0.4014 - val_accuracy: 0.8934 - 1s/epoch - 3ms/step
# Epoch 34/50
# 329/329 - 1s - loss: 0.1070 - accuracy: 0.9585 - val_loss: 0.4244 - val_accuracy: 0.8911 - 1s/epoch - 3ms/step
# Epoch 35/50
# 329/329 - 1s - loss: 0.1040 - accuracy: 0.9601 - val_loss: 0.4404 - val_accuracy: 0.8967 - 1s/epoch - 4ms/step
# Epoch 36/50
# 329/329 - 2s - loss: 0.1015 - accuracy: 0.9610 - val_loss: 0.4151 - val_accuracy: 0.8954 - 2s/epoch - 5ms/step
# Epoch 37/50
# 329/329 - 2s - loss: 0.1029 - accuracy: 0.9605 - val_loss: 0.4640 - val_accuracy: 0.8936 - 2s/epoch - 5ms/step
# Epoch 38/50
# 329/329 - 2s - loss: 0.0928 - accuracy: 0.9646 - val_loss: 0.4343 - val_accuracy: 0.8918 - 2s/epoch - 5ms/step
# Epoch 39/50
# 329/329 - 1s - loss: 0.0934 - accuracy: 0.9645 - val_loss: 0.4591 - val_accuracy: 0.8979 - 1s/epoch - 4ms/step
# Epoch 40/50
# 329/329 - 1s - loss: 0.0821 - accuracy: 0.9687 - val_loss: 0.4891 - val_accuracy: 0.8949 - 1s/epoch - 3ms/step
# Epoch 41/50
# 329/329 - 1s - loss: 0.0931 - accuracy: 0.9644 - val_loss: 0.4946 - val_accuracy: 0.8892 - 1s/epoch - 3ms/step
# Epoch 42/50
# 329/329 - 1s - loss: 0.0838 - accuracy: 0.9675 - val_loss: 0.5018 - val_accuracy: 0.8969 - 1s/epoch - 3ms/step
# Epoch 43/50
# 329/329 - 1s - loss: 0.0850 - accuracy: 0.9672 - val_loss: 0.5222 - val_accuracy: 0.8862 - 1s/epoch - 3ms/step
# Epoch 44/50
# 329/329 - 1s - loss: 0.0834 - accuracy: 0.9675 - val_loss: 0.5394 - val_accuracy: 0.8873 - 1s/epoch - 3ms/step
# Epoch 45/50
# 329/329 - 1s - loss: 0.0737 - accuracy: 0.9717 - val_loss: 0.5294 - val_accuracy: 0.8969 - 1s/epoch - 4ms/step
# Epoch 46/50
# 329/329 - 2s - loss: 0.0717 - accuracy: 0.9727 - val_loss: 0.5301 - val_accuracy: 0.8918 - 2s/epoch - 5ms/step
# Epoch 47/50
# 329/329 - 1s - loss: 0.0744 - accuracy: 0.9717 - val_loss: 0.5628 - val_accuracy: 0.8826 - 1s/epoch - 3ms/step
# Epoch 48/50
# 329/329 - 1s - loss: 0.0780 - accuracy: 0.9695 - val_loss: 0.4885 - val_accuracy: 0.8946 - 1s/epoch - 3ms/step
# Epoch 49/50
# 329/329 - 1s - loss: 0.0720 - accuracy: 0.9726 - val_loss: 0.5776 - val_accuracy: 0.8849 - 1s/epoch - 3ms/step
# Epoch 50/50
# 329/329 - 1s - loss: 0.0659 - accuracy: 0.9748 - val_loss: 0.5912 - val_accuracy: 0.8922 - 1s/epoch - 3ms/step
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0751 - accuracy: 0.9726
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6569 - accuracy: 0.8842
# Train: 0.973, Test: 0.884

# %% [markdown]
# #### Training history visualization

# %%
def plot_history(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# **What could you notice in the loss graph training the model over large number of epochs?**

# %% [markdown]
# ## 1.3.4 Evaluate the model

# %%
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0751 - accuracy: 0.9726
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6569 - accuracy: 0.8842
# Train: 0.973, Test: 0.884

# %% [markdown]
# **Try to play with these parameters (loss and optimizers) in order to see how this choice affects the accuracy. What do you expect? which is faster?**

# %%
# Compile the model you created before using
# nadam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(optimizer=nadam, loss=loss[0], metrics=metrics[0])

batch_size = 128
epochs = 50
# fit your model and save the returned value as "history".
# Use both the train and validation set
# Set both properly the batch size value and the epochs value
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2, validation_data=(x_val, y_val))
# Evaluate the model
score = model.evaluate(x_val, y_val, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 329/329 - 3s - loss: 0.1267 - accuracy: 0.9539 - val_loss: 0.4958 - val_accuracy: 0.8889 - 3s/epoch - 9ms/step
# Epoch 2/50
# 329/329 - 2s - loss: 0.1245 - accuracy: 0.9543 - val_loss: 0.4763 - val_accuracy: 0.8791 - 2s/epoch - 6ms/step
# Epoch 3/50
# 329/329 - 2s - loss: 0.1188 - accuracy: 0.9560 - val_loss: 0.4756 - val_accuracy: 0.8881 - 2s/epoch - 6ms/step
# Epoch 4/50
# 329/329 - 1s - loss: 0.1089 - accuracy: 0.9583 - val_loss: 0.5663 - val_accuracy: 0.8886 - 1s/epoch - 4ms/step
# Epoch 5/50
# 329/329 - 1s - loss: 0.1054 - accuracy: 0.9599 - val_loss: 0.4757 - val_accuracy: 0.8917 - 1s/epoch - 4ms/step
# Epoch 6/50
# 329/329 - 1s - loss: 0.1045 - accuracy: 0.9606 - val_loss: 0.8002 - val_accuracy: 0.8492 - 1s/epoch - 4ms/step
# Epoch 7/50
# 329/329 - 1s - loss: 0.1080 - accuracy: 0.9602 - val_loss: 0.4576 - val_accuracy: 0.8889 - 1s/epoch - 4ms/step
# Epoch 8/50
# 329/329 - 1s - loss: 0.0902 - accuracy: 0.9653 - val_loss: 3.0650 - val_accuracy: 0.7757 - 1s/epoch - 4ms/step
# Epoch 9/50
# 329/329 - 1s - loss: 0.1170 - accuracy: 0.9593 - val_loss: 0.5858 - val_accuracy: 0.8766 - 1s/epoch - 4ms/step
# Epoch 10/50
# 329/329 - 2s - loss: 0.0929 - accuracy: 0.9651 - val_loss: 0.5306 - val_accuracy: 0.8871 - 2s/epoch - 5ms/step
# Epoch 11/50
# 329/329 - 2s - loss: 0.0943 - accuracy: 0.9656 - val_loss: 0.6292 - val_accuracy: 0.8714 - 2s/epoch - 6ms/step
# Epoch 12/50
# 329/329 - 1s - loss: 0.0959 - accuracy: 0.9640 - val_loss: 0.5072 - val_accuracy: 0.8892 - 1s/epoch - 4ms/step
# Epoch 13/50
# 329/329 - 1s - loss: 0.0850 - accuracy: 0.9685 - val_loss: 0.6048 - val_accuracy: 0.8713 - 1s/epoch - 5ms/step
# Epoch 14/50
# 329/329 - 1s - loss: 0.0873 - accuracy: 0.9666 - val_loss: 0.7374 - val_accuracy: 0.8549 - 1s/epoch - 5ms/step
# Epoch 15/50
# 329/329 - 1s - loss: 0.0900 - accuracy: 0.9668 - val_loss: 0.4827 - val_accuracy: 0.8923 - 1s/epoch - 4ms/step
# Epoch 16/50
# 329/329 - 1s - loss: 0.0858 - accuracy: 0.9687 - val_loss: 0.5554 - val_accuracy: 0.8898 - 1s/epoch - 4ms/step
# Epoch 17/50
# 329/329 - 2s - loss: 0.0813 - accuracy: 0.9697 - val_loss: 0.5443 - val_accuracy: 0.8936 - 2s/epoch - 5ms/step
# Epoch 18/50
# 329/329 - 2s - loss: 0.0738 - accuracy: 0.9711 - val_loss: 0.5091 - val_accuracy: 0.8903 - 2s/epoch - 5ms/step
# Epoch 19/50
# 329/329 - 2s - loss: 0.0796 - accuracy: 0.9706 - val_loss: 0.4980 - val_accuracy: 0.8944 - 2s/epoch - 7ms/step
# Epoch 20/50
# 329/329 - 1s - loss: 0.0772 - accuracy: 0.9720 - val_loss: 0.5493 - val_accuracy: 0.8883 - 1s/epoch - 4ms/step
# Epoch 21/50
# 329/329 - 1s - loss: 0.0714 - accuracy: 0.9748 - val_loss: 0.4835 - val_accuracy: 0.8903 - 1s/epoch - 4ms/step
# Epoch 22/50
# 329/329 - 2s - loss: 0.0762 - accuracy: 0.9722 - val_loss: 0.5019 - val_accuracy: 0.8943 - 2s/epoch - 5ms/step
# Epoch 23/50
# 329/329 - 2s - loss: 0.0711 - accuracy: 0.9741 - val_loss: 0.5262 - val_accuracy: 0.8951 - 2s/epoch - 5ms/step
# Epoch 24/50
# 329/329 - 1s - loss: 0.0688 - accuracy: 0.9745 - val_loss: 0.5353 - val_accuracy: 0.8936 - 1s/epoch - 4ms/step
# Epoch 25/50
# 329/329 - 1s - loss: 0.0705 - accuracy: 0.9743 - val_loss: 0.6576 - val_accuracy: 0.8753 - 1s/epoch - 4ms/step
# Epoch 26/50
# 329/329 - 2s - loss: 0.0702 - accuracy: 0.9740 - val_loss: 0.5515 - val_accuracy: 0.8932 - 2s/epoch - 5ms/step
# Epoch 27/50
# 329/329 - 2s - loss: 0.0646 - accuracy: 0.9754 - val_loss: 0.6029 - val_accuracy: 0.8914 - 2s/epoch - 7ms/step
# Epoch 28/50
# 329/329 - 1s - loss: 0.0675 - accuracy: 0.9762 - val_loss: 0.5929 - val_accuracy: 0.8934 - 1s/epoch - 4ms/step
# Epoch 29/50
# 329/329 - 1s - loss: 0.0690 - accuracy: 0.9741 - val_loss: 0.5727 - val_accuracy: 0.8907 - 1s/epoch - 4ms/step
# Epoch 30/50
# 329/329 - 1s - loss: 0.0691 - accuracy: 0.9755 - val_loss: 0.6034 - val_accuracy: 0.8932 - 1s/epoch - 4ms/step
# Epoch 31/50
# 329/329 - 1s - loss: 0.0630 - accuracy: 0.9759 - val_loss: 0.5815 - val_accuracy: 0.8904 - 1s/epoch - 4ms/step
# Epoch 32/50
# 329/329 - 1s - loss: 0.0667 - accuracy: 0.9761 - val_loss: 0.5711 - val_accuracy: 0.8938 - 1s/epoch - 4ms/step
# Epoch 33/50
# 329/329 - 1s - loss: 0.0621 - accuracy: 0.9773 - val_loss: 0.6008 - val_accuracy: 0.8849 - 1s/epoch - 4ms/step
# Epoch 34/50
# 329/329 - 2s - loss: 0.0716 - accuracy: 0.9732 - val_loss: 0.6220 - val_accuracy: 0.8821 - 2s/epoch - 5ms/step
# Epoch 35/50
# 329/329 - 2s - loss: 0.0614 - accuracy: 0.9773 - val_loss: 0.5977 - val_accuracy: 0.8933 - 2s/epoch - 6ms/step
# Epoch 36/50
# 329/329 - 2s - loss: 0.0624 - accuracy: 0.9769 - val_loss: 0.5872 - val_accuracy: 0.8839 - 2s/epoch - 5ms/step
# Epoch 37/50
# 329/329 - 1s - loss: 0.0593 - accuracy: 0.9786 - val_loss: 0.6238 - val_accuracy: 0.8937 - 1s/epoch - 4ms/step
# Epoch 38/50
# 329/329 - 1s - loss: 0.0490 - accuracy: 0.9820 - val_loss: 0.7386 - val_accuracy: 0.8888 - 1s/epoch - 4ms/step
# Epoch 39/50
# 329/329 - 1s - loss: 0.0605 - accuracy: 0.9778 - val_loss: 0.7091 - val_accuracy: 0.8813 - 1s/epoch - 4ms/step
# Epoch 40/50
# 329/329 - 1s - loss: 0.0551 - accuracy: 0.9797 - val_loss: 0.6117 - val_accuracy: 0.8897 - 1s/epoch - 4ms/step
# Epoch 41/50
# 329/329 - 1s - loss: 0.0602 - accuracy: 0.9790 - val_loss: 0.6484 - val_accuracy: 0.8914 - 1s/epoch - 4ms/step
# Epoch 42/50
# 329/329 - 1s - loss: 0.0503 - accuracy: 0.9815 - val_loss: 0.6177 - val_accuracy: 0.8951 - 1s/epoch - 4ms/step
# Epoch 43/50
# 329/329 - 2s - loss: 0.0532 - accuracy: 0.9810 - val_loss: 0.5922 - val_accuracy: 0.8903 - 2s/epoch - 5ms/step
# Epoch 44/50
# 329/329 - 2s - loss: 0.0541 - accuracy: 0.9798 - val_loss: 0.6072 - val_accuracy: 0.8922 - 2s/epoch - 6ms/step
# Epoch 45/50
# 329/329 - 1s - loss: 0.0580 - accuracy: 0.9789 - val_loss: 0.5943 - val_accuracy: 0.8935 - 1s/epoch - 4ms/step
# Epoch 46/50
# 329/329 - 1s - loss: 0.0553 - accuracy: 0.9805 - val_loss: 0.6015 - val_accuracy: 0.8946 - 1s/epoch - 4ms/step
# Epoch 47/50
# 329/329 - 1s - loss: 0.0546 - accuracy: 0.9815 - val_loss: 0.5641 - val_accuracy: 0.8932 - 1s/epoch - 4ms/step
# Epoch 48/50
# 329/329 - 1s - loss: 0.0486 - accuracy: 0.9832 - val_loss: 0.6409 - val_accuracy: 0.8911 - 1s/epoch - 4ms/step
# Epoch 49/50
# 329/329 - 1s - loss: 0.0480 - accuracy: 0.9828 - val_loss: 0.6218 - val_accuracy: 0.8941 - 1s/epoch - 4ms/step
# Epoch 50/50
# 329/329 - 1s - loss: 0.0485 - accuracy: 0.9835 - val_loss: 0.6667 - val_accuracy: 0.8942 - 1s/epoch - 4ms/step
# Test loss: 0.6666675806045532
# Test accuracy: 0.8941666483879089

# %%
plot_history(history)

# %% [markdown]
# # 1.4 Dealing with overfitting
# Given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.<br>
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether).<br>
# How to improve generalization of our model on unseen data?<br>
# In this section we will:
# * 1.3.1 Add weight regularization
# * 1.3.2 Dropout
# * 1.3.3 Early stopping

# %% [markdown]
# ## 1.4.1 Add weight regularization
# A common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular".<br>
# This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights.<br> This cost comes in two flavors:
# * L1 regularization
# * L2 regularization
#
# In tf.keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments.

# %%
from keras.regularizers import L2
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer
model.add(Dense(512, activation='relu', kernel_regularizer=L2(0.001)))
# Add a Dense layer with 256 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer
model.add(Dense(256, activation='relu', kernel_regularizer=L2(0.001)))
# Add a Dense layer with 128 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer
model.add(Dense(128, activation='relu', kernel_regularizer=L2(0.001)))
# Add a Dense layer with 64 neurons, with relu as activation function and a l2 regularizer (with 0.001 as regularization value) as kernel regularizer
model.add(Dense(64, activation='relu', kernel_regularizer=L2(0.001)))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(10, activation='softmax'))

# Compile the model you just created using
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(adam, loss[0], metrics[0])

# fit your model and save the returned value as "history".
# Use both the train and validation set
# Set both properly the batch size value and the epochs value
batch_size = 128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))

# Call the plot_history function to plot the obtained results
plot_history(history)
# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 [==============================] - 2s 5ms/step - loss: 0.9896 - accuracy: 0.7747 - val_loss: 0.6333 - val_accuracy: 0.8513
# Epoch 2/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.6034 - accuracy: 0.8436 - val_loss: 0.5480 - val_accuracy: 0.8586
# Epoch 3/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5374 - accuracy: 0.8562 - val_loss: 0.5251 - val_accuracy: 0.8593
# Epoch 4/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.5076 - accuracy: 0.8636 - val_loss: 0.5056 - val_accuracy: 0.8658
# Epoch 5/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4842 - accuracy: 0.8695 - val_loss: 0.4985 - val_accuracy: 0.8627
# Epoch 6/10
# 329/329 [==============================] - 2s 5ms/step - loss: 0.4671 - accuracy: 0.8727 - val_loss: 0.4795 - val_accuracy: 0.8686
# Epoch 7/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.4547 - accuracy: 0.8760 - val_loss: 0.4734 - val_accuracy: 0.8702
# Epoch 8/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4459 - accuracy: 0.8791 - val_loss: 0.4973 - val_accuracy: 0.8626
# Epoch 9/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4363 - accuracy: 0.8811 - val_loss: 0.5038 - val_accuracy: 0.8542
# Epoch 10/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4309 - accuracy: 0.8818 - val_loss: 0.4882 - val_accuracy: 0.8614
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.4448 - accuracy: 0.8766
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5149 - accuracy: 0.8536
# Train: 0.877, Test: 0.854

# %% [markdown]
# ## 1.4.2 Dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks.<br>
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training.<br>
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5; at test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.

# %%
from keras.layers import Dropout
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(rate=0.3))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(rate=0.3))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dropout layer with 0.3 drop probability
model.add(Dropout(rate=0.3))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(10, activation='softmax'))

# Compile the model you just created using
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(adam, loss[0], metrics[0])

# fit your model and save the returned value as "history".
# Use both the train and validation set
# Set both properly the batch size value and the epochs value
batch_size = 128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))

# Call the plot_history function to plot the obtained results
plot_history(history)
# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 [==============================] - 3s 5ms/step - loss: 0.6803 - accuracy: 0.7496 - val_loss: 0.4508 - val_accuracy: 0.8333
# Epoch 2/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4696 - accuracy: 0.8315 - val_loss: 0.3904 - val_accuracy: 0.8557
# Epoch 3/10
# 329/329 [==============================] - 2s 5ms/step - loss: 0.4274 - accuracy: 0.8444 - val_loss: 0.3795 - val_accuracy: 0.8583
# Epoch 4/10
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3991 - accuracy: 0.8553 - val_loss: 0.3656 - val_accuracy: 0.8677
# Epoch 5/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3792 - accuracy: 0.8619 - val_loss: 0.3622 - val_accuracy: 0.8711
# Epoch 6/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3677 - accuracy: 0.8653 - val_loss: 0.3434 - val_accuracy: 0.8765
# Epoch 7/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3541 - accuracy: 0.8702 - val_loss: 0.3450 - val_accuracy: 0.8763
# Epoch 8/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3457 - accuracy: 0.8742 - val_loss: 0.3395 - val_accuracy: 0.8733
# Epoch 9/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3332 - accuracy: 0.8777 - val_loss: 0.3292 - val_accuracy: 0.8838
# Epoch 10/10
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3249 - accuracy: 0.8806 - val_loss: 0.3225 - val_accuracy: 0.8831
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2669 - accuracy: 0.8989
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3539 - accuracy: 0.8729
# Train: 0.899, Test: 0.873

# %% [markdown]
# ## 1.4.3 Early stopping
# Validation can be used to detect when overfitting starts during supervised training of a neural network; training is then stopped before convergence to avoid the overfitting.<br>

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
import os
# early stopping https://keras.io/callbacks/
my_callback = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# Create checkpoint callback that will save the best model observed during training for later use
checkpoint_path = "output/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(checkpoint_path,monitor='val_loss',save_weights_only=True,verbose=1)

# %%
# Build the model
model = Sequential()
model.add(Flatten())
# Add a Dense layer with 512 neurons, with relu as activation function
model.add(Dense(512, activation='relu'))
# Add a Dense layer with 256 neurons, with relu as activation function
model.add(Dense(256, activation='relu'))
# Add a Dense layer with 128 neurons, with relu as activation function
model.add(Dense(128, activation='relu'))
# Add a Dense layer with 64 neurons, with relu as activation function
model.add(Dense(64, activation='relu'))
# Add a Dense layer with number of neurons equal to the number of classes, with softmax as activation function
model.add(Dense(10, activation='softmax'))

# Compile the model you just created using
# adam optimizer as optimizer
# sparse categorical crossentropy as loss function
# accuracy as metric
model.compile(adam, loss[0], metrics[0])

# fit your model and save the returned value as "history".
# Use both the train and validation set
# Set both properly the batch size value and the epochs value
# Be careful to also set properly the callbacks parameter list
batch_size =128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val), callbacks=[my_callback, cp_callback])

# Call the plot_history function to plot the obtained results
plot_history(history)

# Evaluate
_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/10
# 329/329 [==============================] - ETA: 0s - loss: 0.5524 - accuracy: 0.7966
# Epoch 1: saving model to output/cp.ckpt
# 329/329 [==============================] - 2s 5ms/step - loss: 0.5524 - accuracy: 0.7966 - val_loss: 0.3982 - val_accuracy: 0.8579
# Epoch 2/10
# 314/329 [===========================>..] - ETA: 0s - loss: 0.3747 - accuracy: 0.8629
# Epoch 2: saving model to output/cp.ckpt
# 329/329 [==============================] - 2s 5ms/step - loss: 0.3732 - accuracy: 0.8635 - val_loss: 0.3497 - val_accuracy: 0.8732
# Epoch 3/10
# 318/329 [===========================>..] - ETA: 0s - loss: 0.3322 - accuracy: 0.8782
# Epoch 3: saving model to output/cp.ckpt
# 329/329 [==============================] - 2s 7ms/step - loss: 0.3320 - accuracy: 0.8779 - val_loss: 0.3467 - val_accuracy: 0.8750
# Epoch 4/10
# 322/329 [============================>.] - ETA: 0s - loss: 0.3063 - accuracy: 0.8877
# Epoch 4: saving model to output/cp.ckpt
# 329/329 [==============================] - 2s 6ms/step - loss: 0.3055 - accuracy: 0.8878 - val_loss: 0.3287 - val_accuracy: 0.8805
# Epoch 5/10
# 325/329 [============================>.] - ETA: 0s - loss: 0.2833 - accuracy: 0.8941
# Epoch 5: saving model to output/cp.ckpt
# 329/329 [==============================] - 3s 9ms/step - loss: 0.2833 - accuracy: 0.8940 - val_loss: 0.3285 - val_accuracy: 0.8831
# Epoch 6/10
# 327/329 [============================>.] - ETA: 0s - loss: 0.2732 - accuracy: 0.8981
# Epoch 6: saving model to output/cp.ckpt
# 329/329 [==============================] - 3s 9ms/step - loss: 0.2737 - accuracy: 0.8979 - val_loss: 0.3270 - val_accuracy: 0.8804
# Epoch 7/10
# 322/329 [============================>.] - ETA: 0s - loss: 0.2608 - accuracy: 0.9019
# Epoch 7: saving model to output/cp.ckpt
# 329/329 [==============================] - 2s 7ms/step - loss: 0.2613 - accuracy: 0.9016 - val_loss: 0.3091 - val_accuracy: 0.8897
# Epoch 8/10
# 314/329 [===========================>..] - ETA: 0s - loss: 0.2483 - accuracy: 0.9068
# Epoch 8: saving model to output/cp.ckpt
# 329/329 [==============================] - 2s 6ms/step - loss: 0.2479 - accuracy: 0.9070 - val_loss: 0.3208 - val_accuracy: 0.8864
# Epoch 9/10
# 328/329 [============================>.] - ETA: 0s - loss: 0.2375 - accuracy: 0.9118
# Epoch 9: saving model to output/cp.ckpt
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2375 - accuracy: 0.9118 - val_loss: 0.3257 - val_accuracy: 0.8865
# Epoch 10/10
# 315/329 [===========================>..] - ETA: 0s - loss: 0.2224 - accuracy: 0.9161
# Epoch 10: saving model to output/cp.ckpt
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2235 - accuracy: 0.9158 - val_loss: 0.3204 - val_accuracy: 0.8852
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2158 - accuracy: 0.9196
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3448 - accuracy: 0.8784
# Train: 0.920, Test: 0.878

# %% [markdown]
# #### Load weights
# The saved weights can then be loaded and evaluated any time by calling the load_weights() function.
# In this way I don't have to retrain my net again.

# %%
# This may generate warnings related to saving the state of the optimizer.
# These warnings (and similar warnings throughout this notebook)
# are in place to discourage outdated usage, and can be ignored.
# link https://www.tensorflow.org/tutorials/keras/save_and_restore_models

checkpoint_path = "output/cp.ckpt"

model.load_weights(checkpoint_path)

_, train_acc = model.evaluate(x_train, y_train, verbose=1)
_, test_acc = model.evaluate(x_test, y_test, verbose=1)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2158 - accuracy: 0.9196
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3448 - accuracy: 0.8784
# Train: 0.920, Test: 0.878
